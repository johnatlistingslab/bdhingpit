# %% [markdown]
# # Source A
#
# A notebook for scraping, processing, and storing (to Airtable) the listings in [Source A](https://www.mhvillage.com/parks).

# %% [markdown]
# ## Scrape Data
#
# For this trial, I'll be scraping listings specifically form the state of California.

# %%
from bs4 import BeautifulSoup
import requests
import time

# %%
# Set to california (i.e. /parks/ca)
main_url = 'https://www.mhvillage.com'
url = 'https://www.mhvillage.com/parks/ca'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text)

# %% [markdown]
# Get sublinks to each city.

# %%
city_list = soup.find_all('app-state-item', attrs={'class': 'ng-star-inserted'})
city_name = [c.select_one('a > strong').text.strip() for c in city_list]
links_per_city = [main_url + c.select_one('a')['href'] for c in city_list]

# %% [markdown]
# Loop to each sublink and get data. Note that the displayed items are not exclusively from the city itself only. It displays "nearby" listings as well. Therefore, we use the `ui-city-state-zip-widget` HTML tag to determine first if the listing is from that exact city.

# %%
listings_dct = {}
total_items = 0

for city, link in zip(city_name, links_per_city):
    response_per_city = requests.get(link)
    soup_per_city = BeautifulSoup(response_per_city.text)
    
    listings = soup_per_city.find_all('ui-park-card', attrs={'class': 'ng-star-inserted'})
    
    # Only retain the listings exactly within the city
    listings_dct[city] = [l for l in listings if city in l.find('ui-city-state-zip-widget').text]
    
    total_items += len(listings_dct[city])
    print(f'Currently stored {total_items} listings ...')
    
    # If 50 listings
    if total_items >= 50:
        break
    
    time.sleep(5)
# Out:
# Currently stored 3 listings ...
# Currently stored 8 listings ...
# Currently stored 15 listings ...
# Currently stored 16 listings ...
# Currently stored 18 listings ...
# Currently stored 19 listings ...
# Currently stored 20 listings ...
# Currently stored 24 listings ...
# Currently stored 25 listings ...
# Currently stored 26 listings ...
# Currently stored 33 listings ...
# Currently stored 34 listings ...
# Currently stored 36 listings ...
# Currently stored 40 listings ...
# Currently stored 41 listings ...
# Currently stored 46 listings ...
# Currently stored 65 listings ...

# %% [markdown]
# Generate sublinks and `BeautifulSoup` objects to each listing.

# %%
listings_link_dct = {}

for k in listings_dct.keys():
    listings_link_dct[k] = [main_url + i.find('a')['href'] for i in listings_dct[k]]

# %%
# Create separate BeautifulSoup object per listing so I don't have to make requests every time I try
listings_soup_dct = {}

for city in listings_link_dct.keys():
    listing_links = listings_link_dct[city]
    listings_soup_dct[city] = []
    
    for link in listing_links:
        response_per_listing = requests.get(link)
        listings_soup_dct[city].append(BeautifulSoup(response_per_listing.text))
        
        time.sleep(5)
    
    print(f'Finished extracting for {city}')
# Out:
# Finished extracting for Acampo
# Finished extracting for Acton
# Finished extracting for Adelanto
# Finished extracting for Adin
# Finished extracting for Aerial Acres
# Finished extracting for Agoura Hills
# Finished extracting for Agua Dulce
# Finished extracting for Aguanga
# Finished extracting for Ahwahnee
# Finished extracting for Albion
# Finished extracting for Alpine
# Finished extracting for Alta Loma
# Finished extracting for Altaville
# Finished extracting for Alturas
# Finished extracting for Alviso
# Finished extracting for American Canyon
# Finished extracting for Anaheim

# %%
# Park name = h1
# Street address = ui-street-address-widget (need to strip spaces on both sides and comma on the end)
# City = city variable
# State = ui-city-state-zip-widget (split with ", " then split with space - first one is state)
# ZIP = ui-city-state-zip-widget (split with ", " then split with space - second one is state)
# Phone number = there seems to be none (N/A)
# Website = https://www.mhvillage.com/
# Total lots = Number of sites
# Rent range = 
# Pet policy = 
# Amenities = 
# Latitude = google-map-link attrs={'data-test-id': 'view-on-map'} its `a` child -> href -> split 'query=' then split at ',' get the first
# Longitude = google-map-link attrs={'data-test-id': 'view-on-map'} its `a` child -> href -> split 'query=' then split at ',' get the second
# Source website URL = lnk
# Listing Price = N/A

# %%
listings_details = {}

for city in listings_soup_dct.keys():
    listings_soup_lst = listings_soup_dct[city]
    listings_link_lst = listings_link_dct[city]
    listings_details[city] = []
    
    for sp, lnk in zip(listings_soup_lst, listings_link_lst):
        # Basic info
        park_name = sp.find('h1').text.strip()
        street_address = sp.find('ui-street-address-widget').text.strip().rstrip(',')
        state = sp.find('ui-city-state-zip-widget').text.split(', ')[1].split(' ')[0]
        zipcode = sp.find('ui-city-state-zip-widget').text.split(', ')[1].split(' ')[1]
        phone_number = 'N/A'
        website = 'https://www.mhvillage.com/'
        
        # Total lots
        try:
            total_lots = sp.select('div#forSaleCount').text.strip()
        except:
            total_lots = 'N/A'
        
        # Average monthly rent
        try:
            rent_range_ul = sp.select_one('strong[translate="parks.averageMonthlyRent"] + ul')
            rent_range_bullets = [li.get_text(strip=True) for li in rent_range_ul.find_all('li')]
            rent_range = '\n'.join(rent_range_bullets)
        except:
            rent_range = 'N/A'
        
        # Get pet policy text
        try:
            pet_policy_ul = sp.select_one('strong[translate="parks.petPolicies"] + ul')
            pet_policy_bullets = [li.get_text(strip=True) for li in pet_policy_ul.find_all('li')]
            pet_policy = '\n'.join(pet_policy_bullets)
        except:
            pet_policy = 'N/A'
        
        # Get amenities text
        try:
            amenities_ul = sp.select_one('strong[translate="parks.amenities"] + ul')
            amenities_bullets = [li.get_text(strip=True) for li in amenities_ul.find_all('li')]
            amenities = '\n'.join(amenities_bullets)
            amenities = amenities.rstrip(':')
        except:
            amenities = 'N/A'
        
        # Get latitude and longitude
        gmaps_link = sp.find('google-map-link', attrs={'data-test-id': 'view-on-map'}).find('a')['href']
        latitude = gmaps_link.split('query=')[1].split(',')[0]
        longitude = gmaps_link.split('query=')[1].split(',')[1]
        
        # Other details
        source_url = lnk
        listing_price = 'N/A'
        
        listings_details[city].append(
            {
                'Park Name': park_name,
                'Street Address': street_address,
                'City': city,
                'State': state,
                'ZIP': zipcode,
                'Phone Number': phone_number,
                'Website': website,
                'Total Lots': total_lots,
                'Rent Range': rent_range,
                'Pet Policy': pet_policy,
                'Amenities': amenities,
                'Latitude': latitude,
                'Longitude': longitude,
                'Source Website URL': source_url,
                'Listing Price': listing_price
            }
        )

# %%
listings_details
# Out:
# {'Acampo': [{'Park Name': 'Arbor Mobile Home Park',
#    'Street Address': '19690 North Highway 99',
#    'City': 'Acampo',
#    'State': 'CA',
#    'ZIP': '95220',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: No Pit Bulls',
#    'Amenities': 'Spa\nBasketball Court\nBilliard Room\nLibrary\nWiFi',
#    'Latitude': '38.19398',
#    'Longitude': '-121.19886',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2334',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Mokelumne Beach RV Park',
#    'Street Address': '18450 Calfornia 99',
#    'City': 'Acampo',
#    'State': 'CA',
#    'ZIP': '95220',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '38.14962',
#    'Longitude': '-121.26043',
#    'Source Website URL': 'https://www.mhvillage.com/parks/122348',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Sycamore Mobile Home Park',
#    'Street Address': '24064 North Highway 99',
#    'City': 'Acampo',
#    'State': 'CA',
#    'ZIP': '95220',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '38.19398',
#    'Longitude': '-121.19886',
#    'Source Website URL': 'https://www.mhvillage.com/parks/4608',
#    'Listing Price': 'N/A'}],
#  'Acton': [{'Park Name': 'Acton Country Mobile Home Park',
#    'Street Address': '2501 Sierra Highway',
#    'City': 'Acton',
#    'State': 'CA',
#    'ZIP': '93510',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '705',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Community Approval',
#    'Amenities': 'WiFi',
#    'Latitude': '34.46794',
#    'Longitude': '-118.1824',
#    'Source Website URL': 'https://www.mhvillage.com/parks/40526',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Gemstone Mobile Home Park',
#    'Street Address': '2451 Soledad Canyon Rd',
#    'City': 'Acton',
#    'State': 'CA',
#    'ZIP': '93510',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Community Approval',
#    'Amenities': 'WiFi',
#    'Latitude': '34.47893',
#    'Longitude': '-118.16895',
#    'Source Website URL': 'https://www.mhvillage.com/parks/114970',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Stallion Meadows',
#    'Street Address': '33105 Santiago Road',
#    'City': 'Acton',
#    'State': 'CA',
#    'ZIP': '93510',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '34.46794',
#    'Longitude': '-118.1824',
#    'Source Website URL': 'https://www.mhvillage.com/parks/31206',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Acton KOA',
#    'Street Address': '7601 Soledad Canyon Rd',
#    'City': 'Acton',
#    'State': 'CA',
#    'ZIP': '93510',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '34.43789',
#    'Longitude': '-118.26587',
#    'Source Website URL': 'https://www.mhvillage.com/parks/112718',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Cactus Creek',
#    'Street Address': '3740 Smith St',
#    'City': 'Acton',
#    'State': 'CA',
#    'ZIP': '93510',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '34.46999',
#    'Longitude': '-118.19674',
#    'Source Website URL': 'https://www.mhvillage.com/parks/112836',
#    'Listing Price': 'N/A'}],
#  'Adelanto': [{'Park Name': 'Adelanto High Desert Homes',
#    'Street Address': '17971 Jonathan Street',
#    'City': 'Adelanto',
#    'State': 'CA',
#    'ZIP': '92301',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: 2 small nonaggresive breeds of dogs, or 2 cats, or a combination totaling 2',
#    'Amenities': 'WiFi',
#    'Latitude': '34.66573',
#    'Longitude': '-117.50132',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2249',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Capri Mobile Home Park, LLC',
#    'Street Address': '11420 Lee Ave',
#    'City': 'Adelanto',
#    'State': 'CA',
#    'ZIP': '92301',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '550',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Community Approval',
#    'Amenities': 'WiFi',
#    'Latitude': '34.58369',
#    'Longitude': '-117.41568',
#    'Source Website URL': 'https://www.mhvillage.com/parks/110314',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Sierra Sands',
#    'Street Address': '18772 Bellflower Rd',
#    'City': 'Adelanto',
#    'State': 'CA',
#    'ZIP': '92301',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '500',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Community Approval',
#    'Amenities': 'WiFi',
#    'Latitude': '34.66573',
#    'Longitude': '-117.50132',
#    'Source Website URL': 'https://www.mhvillage.com/parks/51646',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Adelanto Mobile Home Park',
#    'Street Address': '11137 Bartlett Avenue',
#    'City': 'Adelanto',
#    'State': 'CA',
#    'ZIP': '92301',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: 35 Pounds',
#    'Amenities': 'WiFi',
#    'Latitude': '34.66573',
#    'Longitude': '-117.50132',
#    'Source Website URL': 'https://www.mhvillage.com/parks/4589',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Desert Capri Mobile Home Park',
#    'Street Address': '11423 Chamberlaine Way',
#    'City': 'Adelanto',
#    'State': 'CA',
#    'ZIP': '92301',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '420',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '34.66573',
#    'Longitude': '-117.50132',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2589',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Adelanto RV Park',
#    'Street Address': '11301 Airbase Rd',
#    'City': 'Adelanto',
#    'State': 'CA',
#    'ZIP': '92301',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '34.57196',
#    'Longitude': '-117.41869',
#    'Source Website URL': 'https://www.mhvillage.com/parks/120256',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Clover MHP',
#    'Street Address': '11398 Bartlett Ave',
#    'City': 'Adelanto',
#    'State': 'CA',
#    'ZIP': '92301',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '34.57937',
#    'Longitude': '-117.4166',
#    'Source Website URL': 'https://www.mhvillage.com/parks/120698',
#    'Listing Price': 'N/A'}],
#  'Adin': [{'Park Name': 'Butte Creek MH/RV Park',
#    'Street Address': '107 Cemetary Rd #12',
#    'City': 'Adin',
#    'State': 'CA',
#    'ZIP': '96006',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '41.18943',
#    'Longitude': '-120.94674',
#    'Source Website URL': 'https://www.mhvillage.com/parks/115974',
#    'Listing Price': 'N/A'}],
#  'Aerial Acres': [{'Park Name': 'Desert Palm Mobile Home Park',
#    'Street Address': '17669 Frontage Rd',
#    'City': 'Aerial Acres',
#    'State': 'CA',
#    'ZIP': '93523',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '35.00636',
#    'Longitude': '-117.82168',
#    'Source Website URL': 'https://www.mhvillage.com/parks/112054',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Fountain Trailer Park',
#    'Street Address': '16450 Frontage Rd',
#    'City': 'Aerial Acres',
#    'State': 'CA',
#    'ZIP': '93523',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '35.00906',
#    'Longitude': '-117.84281',
#    'Source Website URL': 'https://www.mhvillage.com/parks/112266',
#    'Listing Price': 'N/A'}],
#  'Agoura Hills': [{'Park Name': 'Seminole Springs Mobilehome Park, Inc',
#    'Street Address': '30473 Mulholland Highway',
#    'City': 'Agoura Hills',
#    'State': 'CA',
#    'ZIP': '91301',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: 3 dogs or cats',
#    'Amenities': 'WiFi',
#    'Latitude': '34.10836',
#    'Longitude': '-118.79288',
#    'Source Website URL': 'https://www.mhvillage.com/parks/4381',
#    'Listing Price': 'N/A'}],
#  'Agua Dulce': [{'Park Name': 'Hacienda Vasques Mh Park',
#    'Street Address': '32590 Agua Dulce Canyon Rd',
#    'City': 'Agua Dulce',
#    'State': 'CA',
#    'ZIP': '91390',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '34.53625',
#    'Longitude': '-118.40161',
#    'Source Website URL': 'https://www.mhvillage.com/parks/62883',
#    'Listing Price': 'N/A'}],
#  'Aguanga': [{'Park Name': 'Cowboy Country Campground',
#    'Street Address': '50005 Bradford Rd',
#    'City': 'Aguanga',
#    'State': 'CA',
#    'ZIP': '92536',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '33.49494',
#    'Longitude': '-116.78331',
#    'Source Website URL': 'https://www.mhvillage.com/parks/118500',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Jojoba Hills Ski Resort',
#    'Street Address': '45120 California 79',
#    'City': 'Aguanga',
#    'State': 'CA',
#    'ZIP': '92536',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '33.44707',
#    'Longitude': '-116.87332',
#    'Source Website URL': 'https://www.mhvillage.com/parks/118206',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Oak Springs Ranch',
#    'Street Address': '38901 Reed Valley Rd',
#    'City': 'Aguanga',
#    'State': 'CA',
#    'ZIP': '92536',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '33.55569',
#    'Longitude': '-116.83044',
#    'Source Website URL': 'https://www.mhvillage.com/parks/118270',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Outdoor Resorts Rancho California',
#    'Street Address': '45525 Highway 795',
#    'City': 'Aguanga',
#    'State': 'CA',
#    'ZIP': '92536',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '33.43697',
#    'Longitude': '-116.86534',
#    'Source Website URL': 'https://www.mhvillage.com/parks/118798',
#    'Listing Price': 'N/A'}],
#  'Ahwahnee': [{'Park Name': 'Sierra Meadows RV Park',
#    'Street Address': '46516 Opah Dr',
#    'City': 'Ahwahnee',
#    'State': 'CA',
#    'ZIP': '93601',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '37.3634',
#    'Longitude': '-119.70019',
#    'Source Website URL': 'https://www.mhvillage.com/parks/115028',
#    'Listing Price': 'N/A'}],
#  'Albion': [{'Park Name': 'Albion River Campground',
#    'Street Address': '34500 California 1',
#    'City': 'Albion',
#    'State': 'CA',
#    'ZIP': '95410',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '39.22324',
#    'Longitude': '-123.76806',
#    'Source Website URL': 'https://www.mhvillage.com/parks/115228',
#    'Listing Price': 'N/A'}],
#  'Alpine': [{'Park Name': 'Alpine Oaks Estates',
#    'Street Address': '3505 Alpine Boulevard',
#    'City': 'Alpine',
#    'State': 'CA',
#    'ZIP': '91901',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '810',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Breed restrictions',
#    'Amenities': 'WiFi',
#    'Latitude': '32.78992',
#    'Longitude': '-116.7112',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2280',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Alpine Mobile Home Estates',
#    'Street Address': '2400 Alpine Boulevard',
#    'City': 'Alpine',
#    'State': 'CA',
#    'ZIP': '91901',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '730',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: small pets only, max 25lbs',
#    'Amenities': 'WiFi',
#    'Latitude': '32.78992',
#    'Longitude': '-116.7112',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2278',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Alpine RV Park',
#    'Street Address': '5635 Willows Rd',
#    'City': 'Alpine',
#    'State': 'CA',
#    'ZIP': '91901',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '32.84136',
#    'Longitude': '-116.69207',
#    'Source Website URL': 'https://www.mhvillage.com/parks/121544',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Corral Trailer Park',
#    'Street Address': '2530 Alpine Blvd',
#    'City': 'Alpine',
#    'State': 'CA',
#    'ZIP': '91901',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '32.83512',
#    'Longitude': '-116.75935',
#    'Source Website URL': 'https://www.mhvillage.com/parks/121190',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Crown Hills',
#    'Street Address': '1821 Victoria Park Terrace',
#    'City': 'Alpine',
#    'State': 'CA',
#    'ZIP': '91901',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '32.78992',
#    'Longitude': '-116.7112',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2813',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Little Acre Mobile Home Park',
#    'Street Address': '5553 Willows Rd',
#    'City': 'Alpine',
#    'State': 'CA',
#    'ZIP': '91901',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '32.84154',
#    'Longitude': '-116.69409',
#    'Source Website URL': 'https://www.mhvillage.com/parks/121856',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Rancho Japatul',
#    'Street Address': '21875 Japatul Ln',
#    'City': 'Alpine',
#    'State': 'CA',
#    'ZIP': '91901',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '32.78907',
#    'Longitude': '-116.68319',
#    'Source Website URL': 'https://www.mhvillage.com/parks/121688',
#    'Listing Price': 'N/A'}],
#  'Alta Loma': [{'Park Name': 'Chaparral Heights MHP',
#    'Street Address': '6880 Archibald Avenue',
#    'City': 'Alta Loma',
#    'State': 'CA',
#    'ZIP': '91701',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '730',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: one under 20 lbs',
#    'Amenities': 'Spa\nBocce Ball\nShuffleboard Court\nBilliard Room\nLibrary\nLaundry Facilities\nBoat/RV Storage\nWiFi',
#    'Latitude': '34.12952',
#    'Longitude': '-117.59574',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2662',
#    'Listing Price': 'N/A'}],
#  'Altaville': [{'Park Name': 'Angels Camp RV Resort',
#    'Street Address': '3069 Highway 49 South',
#    'City': 'Altaville',
#    'State': 'CA',
#    'ZIP': '95221',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Breed Restrictions',
#    'Amenities': 'WiFi',
#    'Latitude': '38.04438',
#    'Longitude': '-120.52463',
#    'Source Website URL': 'https://www.mhvillage.com/parks/86061',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Angels Mobile Home Court',
#    'Street Address': '303 North Baker',
#    'City': 'Altaville',
#    'State': 'CA',
#    'ZIP': '95221',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '38.07574',
#    'Longitude': '-120.55242',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2312',
#    'Listing Price': 'N/A'}],
#  'Alturas': [{'Park Name': 'Brass Rail Campgrounds',
#    'Street Address': '515 E 8th St',
#    'City': 'Alturas',
#    'State': 'CA',
#    'ZIP': '96101',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '41.49093',
#    'Longitude': '-120.53748',
#    'Source Website URL': 'https://www.mhvillage.com/parks/115920',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'High Desert Resort',
#    'Street Address': '100 N Court St',
#    'City': 'Alturas',
#    'State': 'CA',
#    'ZIP': '96101',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '41.4844',
#    'Longitude': '-120.54123',
#    'Source Website URL': 'https://www.mhvillage.com/parks/115946',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Nifty Mobile Home & Rv Park',
#    'Street Address': '1401 Thomason Lane',
#    'City': 'Alturas',
#    'State': 'CA',
#    'ZIP': '96101',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '41.5132',
#    'Longitude': '-120.51558',
#    'Source Website URL': 'https://www.mhvillage.com/parks/3787',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Sullys Trailer Park',
#    'Street Address': '602 South East Street',
#    'City': 'Alturas',
#    'State': 'CA',
#    'ZIP': '96101',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '41.5132',
#    'Longitude': '-120.51558',
#    'Source Website URL': 'https://www.mhvillage.com/parks/3293',
#    'Listing Price': 'N/A'}],
#  'Alviso': [{'Park Name': 'Summerset Mobile Estates',
#    'Street Address': '2052 Gold St',
#    'City': 'Alviso',
#    'State': 'CA',
#    'ZIP': '95002',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '1100',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: 1 small dog or cat',
#    'Amenities': 'WiFi',
#    'Latitude': '37.42168',
#    'Longitude': '-121.97578',
#    'Source Website URL': 'https://www.mhvillage.com/parks/5050',
#    'Listing Price': 'N/A'}],
#  'American Canyon': [{'Park Name': 'American Canyon Mobile Home Park',
#    'Street Address': '260 American Canyon Rd',
#    'City': 'American Canyon',
#    'State': 'CA',
#    'ZIP': '94503',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '950',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: 2 per home',
#    'Amenities': 'WiFi',
#    'Latitude': '38.16366',
#    'Longitude': '-122.24452',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2293',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Las Casitas Napa Mobile Home Park',
#    'Street Address': '3000 Broadway Street',
#    'City': 'American Canyon',
#    'State': 'CA',
#    'ZIP': '94503',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '675',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: 2 pets, 22lbs or less',
#    'Amenities': 'WiFi',
#    'Latitude': '38.16307',
#    'Longitude': '-122.25033',
#    'Source Website URL': 'https://www.mhvillage.com/parks/3489',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Olympia Mobilodge Of Napa',
#    'Street Address': '244 American Canyon Road',
#    'City': 'American Canyon',
#    'State': 'CA',
#    'ZIP': '94503',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '800',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: One small per household',
#    'Amenities': 'WiFi',
#    'Latitude': '38.2036',
#    'Longitude': '-122.23195',
#    'Source Website URL': 'https://www.mhvillage.com/parks/3856',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'World Marine Estates',
#    'Street Address': '2555 Flosden Road',
#    'City': 'American Canyon',
#    'State': 'CA',
#    'ZIP': '94503',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '700',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Pet friendly',
#    'Amenities': 'WiFi',
#    'Latitude': '38.2036',
#    'Longitude': '-122.23195',
#    'Source Website URL': 'https://www.mhvillage.com/parks/4970',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Fairgrounds Mobile Estates',
#    'Street Address': '2525 Flosden Road',
#    'City': 'American Canyon',
#    'State': 'CA',
#    'ZIP': '94503',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'WiFi',
#    'Latitude': '38.2036',
#    'Longitude': '-122.23195',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2991',
#    'Listing Price': 'N/A'}],
#  'Anaheim': [{'Park Name': 'Rancho La Paz',
#    'Street Address': '501 E Orangethorpe',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92801',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: 2 indoor pets only. Under 20 lbs',
#    'Amenities': 'WiFi',
#    'Latitude': '33.84778',
#    'Longitude': '-117.95729',
#    'Source Website URL': 'https://www.mhvillage.com/parks/4133',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Anaheim Mobile Estates',
#    'Street Address': '3050 West Ball Road',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92804',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '1450',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: 1-2 cats, Dogs up to 18 lbs',
#    'Amenities': 'WiFi',
#    'Latitude': '33.81042',
#    'Longitude': '-117.97942',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2303',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Sunkist Gardens Mobile Home Park',
#    'Street Address': '1400 South Sunkist Street',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92806',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '1200',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Management Approval',
#    'Amenities': 'Spa\nHorseshoes\nBocce Ball\nBilliard Room\nLibrary\nLaundry Facilities\nFitness Center\nBoat/RV Storage\nWiFi',
#    'Latitude': '33.81338',
#    'Longitude': '-117.87883',
#    'Source Website URL': 'https://www.mhvillage.com/parks/4573',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Pacific Sunset',
#    'Street Address': '211 South Beach Boulevard',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92804',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '1400',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Two small pets',
#    'Amenities': 'WiFi',
#    'Latitude': '33.81042',
#    'Longitude': '-117.97942',
#    'Source Website URL': 'https://www.mhvillage.com/parks/3898',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Casa Hermosa',
#    'Street Address': '525 North Gilbert Street',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92801',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '950',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: 15 lbs or under',
#    'Amenities': 'WiFi',
#    'Latitude': '33.84778',
#    'Longitude': '-117.95729',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2631',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Del Prado Anaheim',
#    'Street Address': '1616 E Euclid St',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92802',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: See Park Manager for Restrictions',
#    'Amenities': 'Spa\nBasketball Court\nBilliard Room\nLaundry Facilities\nBoat/RV Storage\nWiFi',
#    'Latitude': '33.8107',
#    'Longitude': '-117.91684',
#    'Source Website URL': 'https://www.mhvillage.com/parks/5034',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Rio Vista Mobile Estates',
#    'Street Address': '320 North Park Vista Street',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92806',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '2350',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Community Approval',
#    'Amenities': 'WiFi',
#    'Latitude': '33.83099',
#    'Longitude': '-117.86681',
#    'Source Website URL': 'https://www.mhvillage.com/parks/28425',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Anaheim Shores Estates',
#    'Street Address': '1919 West Coronet Avenue',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92801',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '1260',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Community Approval',
#    'Amenities': 'Spa\nBilliard Room\nLibrary\nWiFi',
#    'Latitude': '33.84778',
#    'Longitude': '-117.95729',
#    'Source Website URL': 'https://www.mhvillage.com/parks/5209',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Friendly Village',
#    'Street Address': '5815 East La Palma Avenue',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92807',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '1616',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Community Approval',
#    'Amenities': 'WiFi',
#    'Latitude': '33.85117',
#    'Longitude': '-117.78838',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2532',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Gold Crest Mobile Home Park',
#    'Street Address': '10770 Katella Avenue',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92804',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '1100',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Community Approval',
#    'Amenities': 'WiFi',
#    'Latitude': '33.81042',
#    'Longitude': '-117.97942',
#    'Source Website URL': 'https://www.mhvillage.com/parks/5080',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Anaheim Royal MHP',
#    'Street Address': '1250 N State College Blvd',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92806',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '1050',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: 20 lbs or less',
#    'Amenities': 'WiFi',
#    'Latitude': '33.83099',
#    'Longitude': '-117.86681',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2304',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Cherokee Senior Mobile Home Park',
#    'Street Address': '235 South Beach Boulevard',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92804',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '294',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: 1 dog 2 cats, 25 lbs or less',
#    'Amenities': 'WiFi',
#    'Latitude': '33.81042',
#    'Longitude': '-117.97942',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2673',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Del Este Mobile Estates',
#    'Street Address': '1241 North East Street',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92805',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '1350',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Community Approval',
#    'Amenities': 'WiFi',
#    'Latitude': '33.85168',
#    'Longitude': '-117.9077',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2848',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Del Ray Mobile Home Park',
#    'Street Address': '1949 South Manchester Avenue',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92802',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '1200',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Community Approval',
#    'Amenities': 'WiFi',
#    'Latitude': '33.8107',
#    'Longitude': '-117.91684',
#    'Source Website URL': 'https://www.mhvillage.com/parks/2855',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Golden Skies Mobile Home Park',
#    'Street Address': '100 West Midway Drive',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92805',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '1150',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Community Approval',
#    'Amenities': 'WiFi',
#    'Latitude': '33.82635',
#    'Longitude': '-117.91045',
#    'Source Website URL': 'https://www.mhvillage.com/parks/3140',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Midway Village',
#    'Street Address': '250 W. Midway Dr.',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92805',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '700',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: 1 dog & 1 cat',
#    'Amenities': 'WiFi',
#    'Latitude': '33.8123',
#    'Longitude': '-117.91105',
#    'Source Website URL': 'https://www.mhvillage.com/parks/97723',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Palm Lodge Mobile Home Estates',
#    'Street Address': '2627 East La Palma Avenue',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92806',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: 1 Pet per Household',
#    'Amenities': 'Laundry Facilities\nRestrooms\nDog Park\nWiFi: For Purchase\nBBQ Area',
#    'Latitude': '33.83099',
#    'Longitude': '-117.86681',
#    'Source Website URL': 'https://www.mhvillage.com/parks/3915',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Ponderosa',
#    'Street Address': '2300 South Lewis Street',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92802',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '1121',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: 2 pets 40lbs or less',
#    'Amenities': 'WiFi',
#    'Latitude': '33.79162',
#    'Longitude': '-117.89712',
#    'Source Website URL': 'https://www.mhvillage.com/parks/5125',
#    'Listing Price': 'N/A'},
#   {'Park Name': 'Rancho La Palmas',
#    'Street Address': '825 W. La Palma Avenue',
#    'City': 'Anaheim',
#    'State': 'CA',
#    'ZIP': '92801',
#    'Phone Number': 'N/A',
#    'Website': 'https://www.mhvillage.com/',
#    'Total Lots': 'N/A',
#    'Rent Range': '780',
#    'Pet Policy': 'Pets Allowed: Yes\nPet Restrictions: Community Approval',
#    'Amenities': 'WiFi',
#    'Latitude': '33.84778',
#    'Longitude': '-117.95729',
#    'Source Website URL': 'https://www.mhvillage.com/parks/99465',
#    'Listing Price': 'N/A'}]}

# %% [markdown]
# ## Pass to Airtable

# %%
from pyairtable import Api, Base
from dotenv import load_dotenv
import os

# %% [markdown]
# Load some variables.

# %%
load_dotenv()
# Out:
# True

# %%
AIRTABLE_PAT = os.getenv('AIRTABLE_PAT')
BASE_ID = os.getenv('BASE_ID')
TABLE_NAME = 'Listings'

# %%
api = Api(AIRTABLE_PAT)
base = Base(api, BASE_ID)
table = base.table(TABLE_NAME)

# %% [markdown]
# Reformat dictionary of listings detail.

# %%
records = []

for city in listings_details.keys():
    listings_details_lst = listings_details[city]
    
    for listing in listings_details_lst:
        records.append(listing)

# %%
for r in records:
    table.create(r)

# %% [markdown]
# ## Export in Pandas

# %%
import pandas as pd

# %%
source_A_df = pd.DataFrame(records)

# %%
source_A_df.to_csv('source_A_listings_only.csv')
