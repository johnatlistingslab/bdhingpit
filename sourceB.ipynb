# %% [markdown]
# # Source A
#
# A notebook for scraping, processing, and storing (to Airtable) the listings in [Source B](https://www.mobilehomeparkstore.com/mobile-home-parks-for-sale).

# %%
from bs4 import BeautifulSoup
import requests
import time
import re

# %%
main_url = 'https://www.mobilehomeparkstore.com'
url = 'https://www.mobilehomeparkstore.com/mobile-home-parks-for-sale'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text)

# %%
# Get links to each state
links_to_state = soup.select('.column-list a')
links_to_state = [main_url + l['href'] for l in links_to_state]
links_to_state
# Out:
# ['https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/alabama/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/arizona/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/arkansas/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/california/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/colorado/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/florida/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/georgia/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/idaho/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/illinois/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/indiana/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/iowa/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/kansas/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/kentucky/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/louisiana/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/maine/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/maryland/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/michigan/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/minnesota/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/mississippi/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/missouri/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/montana/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/nebraska/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/nevada/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/new-mexico/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/new-york/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/north-carolina/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/north-dakota/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/ohio/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/oklahoma/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/oregon/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/pennsylvania/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/south-carolina/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/tennessee/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/texas/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/utah/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/virginia/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/washington/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/west-virginia/all',
#  'https://www.mobilehomeparkstore.com//mobile-home-parks-for-sale/wisconsin/all']

# %% [markdown]
# Get state names.

# %%
states = [s.split('/')[-2] for s in links_to_state]

# %% [markdown]
# Go further and get sublinks of each listing/item per state.

# %%
listings_dct = {}
total_items = 0

for s, lnk in zip(states, links_to_state):
    response_state = requests.get(lnk)
    soup_state = BeautifulSoup(response_state.text)
    
    listings = soup_state.select('div.item-listing div.item')
    listings_dct[s] = [main_url + l.select_one('a')['href'] for l in listings]
    
    total_items += len(listings_dct[s])
    print(f'Processed {s}. Currently stored {total_items} listings ...')
    
    # If 50 listings
    if total_items >= 50:
        break
    
    time.sleep(5)
# Out:
# Processed alabama. Currently stored 11 listings ...
# Processed arizona. Currently stored 14 listings ...
# Processed arkansas. Currently stored 17 listings ...
# Processed california. Currently stored 28 listings ...
# Processed colorado. Currently stored 35 listings ...
# Processed florida. Currently stored 55 listings ...

# %% [markdown]
# Generate `BeautifulSoup` object to each listing.

# %%
# Create separate BeautifulSoup object per listing so I don't have to make requests every time I try
listings_soup_dct = {}

for state in listings_dct.keys():
    listing_links = listings_dct[state]
    listings_soup_dct[state] = []
    
    for link in listing_links:
        response_per_listing = requests.get(link)
        listings_soup_dct[state].append(BeautifulSoup(response_per_listing.text))
        
        time.sleep(5)
    
    print(f'Finished extracting for {state}')
# Out:
# Finished extracting for alabama
# Finished extracting for arizona
# Finished extracting for arkansas
# Finished extracting for california
# Finished extracting for colorado
# Finished extracting for florida

# %%
# Park name = h1 text > re.split(r'\n+', text) [p for p in re.split(r'\n+', text) if p]
# Street address = Same above but use second part and just parse further
# City = Get from h1 as well
# State = Get from h1 as well
# ZIP = Get from h1 as well
# Phone number = Go to contact broker/seller link
# Website = https://www.mobilehomeparkstore.com/
# Total lots = 
# Rent range = 
# Pet policy = 
# Amenities = 
# Latitude = google-map-link attrs={'data-test-id': 'view-on-map'} its `a` child -> href -> split 'query=' then split at ',' get the first
# Longitude = google-map-link attrs={'data-test-id': 'view-on-map'} its `a` child -> href -> split 'query=' then split at ',' get the second
# Source website URL = lnk
# Listing Price = N/A
# Out:
# '\nSandra Ball . Asso. Broker, Coldwell Banker Mcmillan\n\n\n8374 County Road 222, Trinity, AL 35673\n\n\n\n\n\n'

# %%
def get_name_and_address(soup):
    header = soup.select_one('h1').text
    header_split = [p for p in re.split(r'\n+', header) if p]
    park_name = header_split[0]
    
    address_split = header_split[1].split(', ')
    
    if len(address_split) == 3:
        street_address = address_split[0]
        city = address_split[1]
        state = address_split[2].split(' ')[0]
        zipcode = address_split[2].split(' ')[1]
    elif len(address_split) == 2:
        street_address = 'N/A'
        city = address_split[0]
        state_zipcode_split = address_split[1].split(' ')
        
        if len(state_zipcode_split) == 2:
            state = address_split[1].split(' ')[0]
            zipcode = address_split[1].split(' ')[1]
        elif len(state_zipcode_split) == 1:
            state = address_split[1].split(' ')[0]
            zipcode = 'N/A'
        
    return park_name, street_address, city, state, zipcode

# %%
def find_phone_number(soup):
    contact_button = soup.select_one('turbo-frame#contact_main_col_regular')
    
    if contact_button:
        contact_link = main_url + contact_button.select_one('a')['href']
        
        requests_contact = requests.get(contact_link)
        soup_contact = BeautifulSoup(requests_contact.text)
        
        phone = soup_contact.select_one('a#dlg_phone_button').text
        
        phone_clean = re.sub(r'[^\d]', '', phone)
        phone_clean = '(' + phone_clean[0:3] + ')' + phone_clean[3:6] + '-' + phone_clean[6:]
        
        time.sleep(5)
        
        return phone_clean
    
    return 'N/A'

# %%
def find_total_lots(soup):
    for div in soup.select('div.col-lg-6'):
        h3 = div.find('h3')
        
        # First, find the div with containing park info
        if h3 and 'Park Information' in h3.get_text(strip=True):
            # Find table row containing number of MH lots
            for row in div.select('tr'):
                if 'Number of MH Lots' in row.get_text(strip=True):
                    lots = row.select('td')[1].text
                    return lots
    
    return 'N/A'

# %%
def find_lot_rent(soup):
    for div in soup.select('div.col-lg-6'):
        h3 = div.find('h3')
        
        # First, find the div with containing park info
        if h3 and 'Park Information' in h3.get_text(strip=True):
            # Find table row containing number of MH lots
            for row in div.select('tr'):
                if 'Average MH Lot Rent' in row.get_text(strip=True):
                    lots = row.select('td')[1].text
                    return lots
    
    return 'N/A'

# %%
def find_amenities(soup):
    for h3 in soup.select('h3.headline'):
        if 'Amenities' in h3.text:
            amenities_ul = h3.find_next_sibling('ul')
            amenities_bullets = [li.get_text(strip=True) for li in amenities_ul.find_all('li')]
            amenities = '\n'.join(amenities_bullets)
            
            return amenities
    
    return 'N/A'

# %%
def find_listing_price(soup):
    for h1 in soup.select('h1'):
        if 'For Sale' in h1.text:
            return re.sub(r'[^\d]', '', h1.text)

# %%
listings_details = {}

for state in listings_soup_dct.keys():
    listings_soup_lst = listings_soup_dct[state]
    listings_link_lst = listings_dct[state]
    listings_details[state] = []
    
    for sp, lnk in zip(listings_soup_lst, listings_link_lst):
        # Park name and address
        try:
            park_name, street_address, city, state2, zipcode = get_name_and_address(sp)
        except:
            header = soup.select_one('h1').text
            header_split = [p for p in re.split(r'\n+', header) if p]
            park_name = header_split[0]
        
        # phone number
        phone_number = find_phone_number(sp)
        
        # website
        website = main_url
        
        # Total lots
        total_lots = find_total_lots(sp)
        
        # Rent range
        rent_range = find_lot_rent(sp).strip('$')
        
        # Get pet policies
        pet_policy = 'N/A'
        
        # Get amenities
        amenities = find_amenities(sp)
        
        # Get latitude and longitude
        latitude = 'N/A'
        longitude = 'N/A'
        
        # Source website URL
        source_url = lnk
        
        # Listing price
        listing_price = find_listing_price(sp)
        
        listings_details[state].append(
            {
                'Park Name': park_name,
                'Street Address': street_address,
                'City': city,
                'State': state2,
                'ZIP': zipcode,
                'Phone Number': phone_number,
                'Website': website,
                'Total Lots': total_lots,
                'Rent Range': rent_range,
                'Pet Policy': pet_policy,
                'Amenities': amenities,
                'Latitude': latitude,
                'Longitude': longitude,
                'Source Website URL': source_url,
                'Listing Price': listing_price
            }
        )

# %%
listings_details
# Out:
# {'alabama': [{'Park Name': 'Sandra Ball . Asso. Broker, Coldwell Banker Mcmillan',
#    'Street Address': '8374 County Road 222',
#    'City': 'Trinity',
#    'State': 'AL',
#    'ZIP': '35673',
#    'Phone Number': '(256)642-9903',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6957345-sandra-ball-asso-broker-coldwell-banker-mcmillan-for-sale-in-trinity-al',
#    'Listing Price': '1'},
#   {'Park Name': 'Royal Palm Estates',
#    'Street Address': '1435 County Road 73',
#    'City': 'Slocomb',
#    'State': 'AL',
#    'ZIP': '36375',
#    'Phone Number': '(316)655-8405',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '77',
#    'Rent Range': '459',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6925686-royal-palm-estates-for-sale-in-slocomb-al',
#    'Listing Price': None},
#   {'Park Name': 'Sierra Meadows MHP',
#    'Street Address': '296 Sandy Lane',
#    'City': 'Troy',
#    'State': 'AL',
#    'ZIP': '36081',
#    'Phone Number': '(423)483-0492',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '50',
#    'Rent Range': '450',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6894610-sierra-meadows-mhp-for-sale-in-troy-al',
#    'Listing Price': '650000'},
#   {'Park Name': 'The Cove Mobile Home Park',
#    'Street Address': '8510 Old Sardis Road',
#    'City': 'Morris',
#    'State': 'AL',
#    'ZIP': '35116',
#    'Phone Number': '(251)591-9390',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '55',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6878816-the-cove-mobile-home-park-for-sale-in-morris-al',
#    'Listing Price': '2500000'},
#   {'Park Name': 'Mobile Home Park and Self-Storage in Birmingham MSA',
#    'Street Address': 'N/A',
#    'City': 'Chelsea',
#    'State': 'AL',
#    'ZIP': 'N/A',
#    'Phone Number': '(404)876-1640',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '32',
#    'Rent Range': '425',
#    'Pet Policy': 'N/A',
#    'Amenities': 'Storage',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6859758-mobile-home-park-and-self-storage-in-birmingham-msa-for-sale-in-chelsea-al',
#    'Listing Price': '4995000'},
#   {'Park Name': 'Hidden Acres Mobile Home Park',
#    'Street Address': '4915 U.S. 80',
#    'City': 'Selma',
#    'State': 'AL',
#    'ZIP': '36701',
#    'Phone Number': '(561)479-1588',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '201',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6838808-hidden-acres-mobile-home-park-for-sale-in-selma-al',
#    'Listing Price': '2300000'},
#   {'Park Name': 'Opp Estates MHC',
#    'Street Address': '100 Lunsford Circle',
#    'City': 'Opp',
#    'State': 'AL',
#    'ZIP': '36467',
#    'Phone Number': '(217)202-0924',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '73',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6835167-opp-estates-mhc-for-sale-in-opp-al',
#    'Listing Price': '2200000'},
#   {'Park Name': 'Pecan Hill Mobile Home Park',
#    'Street Address': 'N/A',
#    'City': 'Greensboro',
#    'State': 'AL',
#    'ZIP': '36744',
#    'Phone Number': '(954)937-6150',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '56',
#    'Rent Range': '300',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6780983-pecan-hill-mobile-home-park-for-sale-in-greensboro-al',
#    'Listing Price': '649000'},
#   {'Park Name': 'Forestdale MHC',
#    'Street Address': '2926 Una Street',
#    'City': 'Birmingham',
#    'State': 'AL',
#    'ZIP': '35214',
#    'Phone Number': '(423)483-0492',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '185',
#    'Rent Range': '391',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6768429-forestdale-mhc-for-sale-in-birmingham-al',
#    'Listing Price': '4000000'},
#   {'Park Name': 'Southeast Portfolio',
#    'Street Address': '15928 Dean Drive',
#    'City': 'Brookwood',
#    'State': 'AL',
#    'ZIP': '35444',
#    'Phone Number': '(704)831-4643',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '638',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6730618-southeast-portfolio-for-sale-in-brookwood-al',
#    'Listing Price': ''},
#   {'Park Name': 'Alabama MHP Fire Sale',
#    'Street Address': 'N/A',
#    'City': 'Linden',
#    'State': 'AL',
#    'ZIP': '36748',
#    'Phone Number': '(727)592-2418',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '26',
#    'Rent Range': '250',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6838746-alabama-mhp-fire-sale-for-sale-in-linden-al',
#    'Listing Price': None}],
#  'arizona': [{'Park Name': '18 space Mobile  Home Community with 5 Plex included  ',
#    'Street Address': '121 West Main Street',
#    'City': 'Avondale',
#    'State': 'AZ',
#    'ZIP': '85323',
#    'Phone Number': '(520)850-4000',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '23',
#    'Rent Range': '700',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6929775-18-space-mobile-home-community-with-5-plex-included-for-sale-in-avondale-az',
#    'Listing Price': '1750000'},
#   {'Park Name': 'Phoenix Arizona Mobile Home Park | Sands MHP',
#    'Street Address': '3302 East Van Buren Street',
#    'City': 'Phoenix',
#    'State': 'AZ',
#    'ZIP': '85008',
#    'Phone Number': '(561)479-1588',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '66',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6827366-phoenix-arizona-mobile-home-park-sands-mhp-for-sale-in-phoenix-az',
#    'Listing Price': '5900000'},
#   {'Park Name': 'RV Community with stick built, manufactured and community laundry',
#    'Street Address': '631 West Hill Street',
#    'City': 'Superior',
#    'State': 'AZ',
#    'ZIP': '85173',
#    'Phone Number': '(623)400-8864',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '16',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'Laundromat',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6878815-rv-community-with-stick-built-manufactured-and-community-laundry-for-sale-in-superior-az',
#    'Listing Price': '650000'}],
#  'arkansas': [{'Park Name': 'Nashville MHP Estates',
#    'Street Address': '121 South Pine Street',
#    'City': 'Nashville',
#    'State': 'AR',
#    'ZIP': '71852',
#    'Phone Number': '(217)202-0924',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '32',
#    'Rent Range': '250',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6948164-nashville-mhp-estates-for-sale-in-nashville-ar',
#    'Listing Price': '925000'},
#   {'Park Name': 'Meadow Wood Community',
#    'Street Address': '5041 U.S. 61',
#    'City': 'Blytheville',
#    'State': 'AR',
#    'ZIP': '72315',
#    'Phone Number': '(217)202-0924',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '75',
#    'Rent Range': '0',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6929918-meadow-wood-community-for-sale-in-blytheville-ar',
#    'Listing Price': '475000'},
#   {'Park Name': 'Little Rock Metro MH/Land Portfolio',
#    'Street Address': 'N/A',
#    'City': 'Little Rock',
#    'State': 'AR',
#    'ZIP': 'N/A',
#    'Phone Number': '(217)202-0924',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '101',
#    'Rent Range': '722',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6927669-little-rock-metro-mh-land-portfolio-for-sale-in-little-rock-ar',
#    'Listing Price': '8400000'}],
#  'california': [{'Park Name': 'NorCal MHC Portfolio ',
#    'Street Address': 'N/A',
#    'City': 'Yuba City',
#    'State': 'CA',
#    'ZIP': 'N/A',
#    'Phone Number': '(209)444-6651',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '145',
#    'Rent Range': '551',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6940123-norcal-mhc-portfolio-for-sale-in-yuba-city-ca',
#    'Listing Price': ''},
#   {'Park Name': 'Mobile Home Parks for Sale',
#    'Street Address': 'N/A',
#    'City': 'Yuba City',
#    'State': 'CA',
#    'ZIP': 'N/A',
#    'Phone Number': '(951)500-6140',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '124',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'Pool',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6924372-trona-trailer-park-for-sale-in-california',
#    'Listing Price': '699000'},
#   {'Park Name': 'Accepting offers until May 30, 2025',
#    'Street Address': 'N/A',
#    'City': 'Redding',
#    'State': 'CA',
#    'ZIP': 'N/A',
#    'Phone Number': '(801)721-6819',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6897267-accepting-offers-until-may-30-2025-for-sale-in-redding-ca',
#    'Listing Price': ''},
#   {'Park Name': 'Investor Alert – MHP Project  & Passive Income',
#    'Street Address': '401 Sterling Road',
#    'City': 'Pearsonville',
#    'State': 'CA',
#    'ZIP': '93527',
#    'Phone Number': '(424)262-0392',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6896209-investor-alert-mhp-project-passive-income-for-sale-in-pearsonville-ca',
#    'Listing Price': '249000'},
#   {'Park Name': 'Riverside Crossing Mobile Home Park',
#    'Street Address': '24660 Tehama Vina Road',
#    'City': 'Los Molinos',
#    'State': 'CA',
#    'ZIP': '96055',
#    'Phone Number': '(561)479-1588',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '69',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6838809-riverside-crossing-mobile-home-park-for-sale-in-los-molinos-ca',
#    'Listing Price': '2750000'},
#   {'Park Name': 'MORONGO MOBILE MANOR',
#    'Street Address': '49609 Paradise Avenue',
#    'City': 'Morongo Valley',
#    'State': 'CA',
#    'ZIP': '92256',
#    'Phone Number': '(626)383-0951',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '21',
#    'Rent Range': '528',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6835207-morongo-mobile-manor-for-sale-in-morongo-valley-ca',
#    'Listing Price': '1300000'},
#   {'Park Name': 'Hidden Creek Retreat Park',
#    'Street Address': '14721 Pioneer Volcano Road',
#    'City': 'Pine Grove',
#    'State': 'CA',
#    'ZIP': '95665',
#    'Phone Number': '(209)418-8630',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6827884-hidden-creek-retreat-park-for-sale-in-pine-grove-ca',
#    'Listing Price': '599000'},
#   {'Park Name': 'Clearlake 3 Lot Portfolio, $230K!!!!',
#    'Street Address': '15811 44th Avenue',
#    'City': 'Clearlake',
#    'State': 'CA',
#    'ZIP': '95422',
#    'Phone Number': '(510)915-0092',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/1877933-clearlake-3-lot-portfolio-230k-for-sale-in-clearlake-ca',
#    'Listing Price': '230000'},
#   {'Park Name': 'Oak Shadows Land Development, San Andreas',
#    'Street Address': 'Buckskin Way',
#    'City': 'San Andreas',
#    'State': 'CA',
#    'ZIP': '95249',
#    'Phone Number': '(510)915-0092',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '80',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/1296875-oak-shadows-land-development-san-andreas-for-sale-in-san-andreas-ca',
#    'Listing Price': '635000'},
#   {'Park Name': 'Pine Grove Mobile Home Park',
#    'Street Address': 'N/A',
#    'City': 'Mcarthur',
#    'State': 'CA',
#    'ZIP': 'N/A',
#    'Phone Number': '(510)260-7349',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '12',
#    'Rent Range': '400',
#    'Pet Policy': 'N/A',
#    'Amenities': 'Laundromat\nStorage',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6930708-pine-grove-mobile-home-park-for-sale-in-mcarthur-ca',
#    'Listing Price': '699000'},
#   {'Park Name': 'Madrone Mobile Home Park',
#    'Street Address': '2510 U.S. 199',
#    'City': 'Crescent City',
#    'State': 'CA',
#    'ZIP': '95531',
#    'Phone Number': '(831)373-3013',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/3802525-madrone-mobile-home-park-for-sale-in-crescent-city-ca',
#    'Listing Price': '4200000'}],
#  'colorado': [{'Park Name': 'Mobile Home Park',
#    'Street Address': '3223 South Santa Fe Drive',
#    'City': 'Englewood',
#    'State': 'CO',
#    'ZIP': '80110',
#    'Phone Number': '(303)407-9784',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6955288-mobile-home-park-for-sale-in-englewood-co',
#    'Listing Price': '1750000'},
#   {'Park Name': 'Mobile Home Park',
#    'Street Address': '3070 South Lipan Street',
#    'City': 'Englewood',
#    'State': 'CO',
#    'ZIP': '80110',
#    'Phone Number': '(303)407-9784',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6955287-mobile-home-park-for-sale-in-englewood-co',
#    'Listing Price': '3000000'},
#   {'Park Name': '24-Space Mobile Home Park',
#    'Street Address': '2990 South Lipan Street',
#    'City': 'Englewood',
#    'State': 'CO',
#    'ZIP': '80110',
#    'Phone Number': '(303)407-9784',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '24',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6955286-24-space-mobile-home-park-for-sale-in-englewood-co',
#    'Listing Price': '3750000'},
#   {'Park Name': 'Aspen Homes Mobile Home Community',
#    'Street Address': '875 Monument Street',
#    'City': 'Calhan',
#    'State': 'CO',
#    'ZIP': '80808',
#    'Phone Number': '(719)257-3949',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '22',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6696247-aspen-homes-mobile-home-community-for-sale-in-calhan-co',
#    'Listing Price': '1400000'},
#   {'Park Name': '8 Lot MHP with Seller Financing in Manzanola, CO',
#    'Street Address': '115 South Park Street',
#    'City': 'Manzanola',
#    'State': 'CO',
#    'ZIP': '81058',
#    'Phone Number': '(719)650-3884',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '8',
#    'Rent Range': '428',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6832388-8-lot-mhp-with-seller-financing-in-manzanola-co-for-sale-in-manzanola-co',
#    'Listing Price': '269900'},
#   {'Park Name': 'Rare Investment Opportunity- 12 lot Mobile Home Park in Aurora, Colorado',
#    'Street Address': '1434 Idalia Court',
#    'City': 'Aurora',
#    'State': 'CO',
#    'ZIP': '80011',
#    'Phone Number': '(719)650-3884',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '12',
#    'Rent Range': '1,150',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6830834-rare-investment-opportunity-12-lot-mobile-home-park-in-aurora-colorado-for-sale-in-aurora-co',
#    'Listing Price': '1950000'},
#   {'Park Name': 'Sterling CO - 23 space MHP  7% cap rate',
#    'Street Address': '516 Kochia Way',
#    'City': 'Sterling',
#    'State': 'CO',
#    'ZIP': '80751',
#    'Phone Number': '(208)724-7443',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '23',
#    'Rent Range': '475',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/3884342-sterling-co-23-space-mhp-7-cap-rate-for-sale-in-sterling-co',
#    'Listing Price': '1300000'}],
#  'florida': [{'Park Name': 'Camp Margaritaville Auburndale Resort & Cabana Cabins',
#    'Street Address': '361 Denton Avenue',
#    'City': 'Auburndale',
#    'State': 'FL',
#    'ZIP': '33823',
#    'Phone Number': '(561)479-1588',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'Laundromat\nPool\nClub House\nStorage\nHandicap Accessible',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6957317-camp-margaritaville-auburndale-resort-cabana-cabins-for-sale-in-auburndale-fl',
#    'Listing Price': '86000000'},
#   {'Park Name': '3,500 Pad Manufactured Home Community - Selling 4% Equity ',
#    'Street Address': 'N/A',
#    'City': 'Southport',
#    'State': 'FL',
#    'ZIP': '32409',
#    'Phone Number': '(561)702-0880',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '3500',
#    'Rent Range': '600',
#    'Pet Policy': 'N/A',
#    'Amenities': 'Pool\nClub House\nStorage\nHandicap Accessible',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6677277-3-500-pad-manufactured-home-community-selling-4-equity-for-sale-in-southport-fl',
#    'Listing Price': '600000'},
#   {'Park Name': 'Callaway Mobile Home Park',
#    'Street Address': '208 North Highway 22 A',
#    'City': 'Panama City',
#    'State': 'FL',
#    'ZIP': '32404',
#    'Phone Number': '(404)626-7052',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '41',
#    'Rent Range': '650',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6952682-callaway-mobile-home-park-for-sale-in-panama-city-fl',
#    'Listing Price': '3100000'},
#   {'Park Name': 'Turnkey Mobile Home Investment Portfolio – $1.95M – Strong Cash Flow & Expansion Potential',
#    'Street Address': 'N/A',
#    'City': 'Tallahassee',
#    'State': 'FL',
#    'ZIP': 'N/A',
#    'Phone Number': '(850)666-0324',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6926912-turnkey-mobile-home-investment-portfolio-1-95m-strong-cash-flow-expansion-potential-for-sale-in-tallahassee-fl',
#    'Listing Price': '1950000'},
#   {'Park Name': 'Lake Weir Pines Mobile Home Park',
#    'Street Address': '14455 East Highway 25',
#    'City': 'Ocklawaha',
#    'State': 'FL',
#    'ZIP': '32179',
#    'Phone Number': '(303)912-3056',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'Handicap Accessible',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6924858-lake-weir-pines-mobile-home-park-for-sale-in-ocklawaha-fl',
#    'Listing Price': '2999999'},
#   {'Park Name': 'Calusa Cove',
#    'Street Address': '4700 San Michel Drive',
#    'City': 'Fort Myers',
#    'State': 'FL',
#    'ZIP': '33908',
#    'Phone Number': '(239)848-2050',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '110',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6907394-calusa-cove-for-sale-in-fort-myers-fl',
#    'Listing Price': '8699500'},
#   {'Park Name': 'Cycle Drive Mobile Home Park ',
#    'Street Address': '2700 Cycle Drive',
#    'City': 'Pensacola',
#    'State': 'FL',
#    'ZIP': '32526',
#    'Phone Number': '(850)610-1555',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '26',
#    'Rent Range': '400',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6907392-cycle-drive-mobile-home-park-for-sale-in-pensacola-fl',
#    'Listing Price': '1250000'},
#   {'Park Name': 'Mobile Home Park Dev. Site 386 Units ',
#    'Street Address': '6725 South Rainbow Point',
#    'City': 'Homosassa',
#    'State': 'FL',
#    'ZIP': '34446',
#    'Phone Number': '(813)370-0953',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '386',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6903663-mobile-home-park-dev-site-386-units-for-sale-in-homosassa-fl',
#    'Listing Price': '800000'},
#   {'Park Name': '2 Park Portfolio Tampa, FL',
#    'Street Address': '6700 North Rome Avenue',
#    'City': 'Tampa',
#    'State': 'FL',
#    'ZIP': '33604',
#    'Phone Number': '(423)483-0492',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '125',
#    'Rent Range': '894',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6892278-2-park-portfolio-tampa-fl-for-sale-in-tampa-fl',
#    'Listing Price': '16500000'},
#   {'Park Name': 'A Touch of Mink MHP',
#    'Street Address': '22127 U.S. 441',
#    'City': 'High Springs',
#    'State': 'FL',
#    'ZIP': '32643',
#    'Phone Number': '(352)660-5606',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '16',
#    'Rent Range': '700',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6845497-a-touch-of-mink-mhp-for-sale-in-high-springs-fl',
#    'Listing Price': '840000'},
#   {'Park Name': 'Lake Istokpoga Dream',
#    'Street Address': '44 Crawford Drive',
#    'City': 'Lake Placid',
#    'State': 'FL',
#    'ZIP': '33852',
#    'Phone Number': '(954)552-2512',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '17',
#    'Rent Range': '1,500',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6836933-lake-istokpoga-dream-for-sale-in-lake-placid-fl',
#    'Listing Price': '2490000'},
#   {'Park Name': 'Oakwoods MHC',
#    'Street Address': '290 Ada Court',
#    'City': 'Tallahassee',
#    'State': 'FL',
#    'ZIP': '32305',
#    'Phone Number': '(423)483-0492',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '73',
#    'Rent Range': '431',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6835204-oakwoods-mhc-for-sale-in-tallahassee-fl',
#    'Listing Price': '2500000'},
#   {'Park Name': 'Suzy Q Lane',
#    'Street Address': 'Suzy Q Lane',
#    'City': 'Crestview',
#    'State': 'FL',
#    'ZIP': '32539',
#    'Phone Number': '(850)243-8477',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': 'N/A',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6833903-suzy-q-lane-for-sale-in-crestview-fl',
#    'Listing Price': '1200000'},
#   {'Park Name': 'Melbourne 55+ MHP',
#    'Street Address': '900 East Strawbridge Avenue',
#    'City': 'Melbourne',
#    'State': 'FL',
#    'ZIP': '32901',
#    'Phone Number': '(423)483-0492',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '37',
#    'Rent Range': '581',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6827885-melbourne-55-mhp-for-sale-in-melbourne-fl',
#    'Listing Price': '4500000'},
#   {'Park Name': 'Summerfield, FL MHP DEVELOPMENT PORTFOLIO',
#    'Street Address': '11987 S Us Hwy 301',
#    'City': 'Belleview',
#    'State': 'FL',
#    'ZIP': '33420',
#    'Phone Number': '(217)202-0924',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '80',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'Pool\nClub House',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6821742-summerfield-fl-mhp-development-portfolio-for-sale-in-belleview-fl',
#    'Listing Price': '2850000'},
#   {'Park Name': 'Ruby Lane Mobile Home Park - Bonifay, FL',
#    'Street Address': '2344 Ruby Lane',
#    'City': 'Bonifay',
#    'State': 'FL',
#    'ZIP': '32425',
#    'Phone Number': '(844)328-5905',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '5',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6800783-ruby-lane-mobile-home-park-bonifay-fl-for-sale-in-bonifay-fl',
#    'Listing Price': '200000'},
#   {'Park Name': '5 UNIT MOBILE HOME PARK',
#    'Street Address': '3431 Southeast 38th Avenue',
#    'City': 'Okeechobee',
#    'State': 'FL',
#    'ZIP': '34974',
#    'Phone Number': '(863)801-2101',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '5',
#    'Rent Range': '1,100',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6466128-5-unit-mobile-home-park-for-sale-in-okeechobee-fl',
#    'Listing Price': '525000'},
#   {'Park Name': 'Edgewater Mobile Home Park',
#    'Street Address': '1586 Southeast Country Club Road',
#    'City': 'Lake City',
#    'State': 'FL',
#    'ZIP': '32025',
#    'Phone Number': '(813)546-8778',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '58',
#    'Rent Range': '900',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/5880487-edgewater-mobile-home-park-for-sale-in-lake-city-fl',
#    'Listing Price': '2350000'},
#   {'Park Name': 'River Bluff Resort',
#    'Street Address': '14725 Northwest 1st Parkway',
#    'City': 'Okeechobee',
#    'State': 'FL',
#    'ZIP': '34972',
#    'Phone Number': '(305)345-3738',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '14',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/5219009-river-bluff-resort-for-sale-in-okeechobee-fl',
#    'Listing Price': '1649900'},
#   {'Park Name': '3 Homes 45 min North of Panama City Beach',
#    'Street Address': 'N/A',
#    'City': 'Wausau',
#    'State': 'FL',
#    'ZIP': 'N/A',
#    'Phone Number': '(850)740-9506',
#    'Website': 'https://www.mobilehomeparkstore.com',
#    'Total Lots': '3',
#    'Rent Range': 'N/A',
#    'Pet Policy': 'N/A',
#    'Amenities': 'N/A',
#    'Latitude': 'N/A',
#    'Longitude': 'N/A',
#    'Source Website URL': 'https://www.mobilehomeparkstore.com//mobile-home-parks/6935795-3-homes-45-min-north-of-panama-city-beach-for-sale-in-wausau-fl',
#    'Listing Price': '165000'}]}

# %% [markdown]
# ## Pass to Airtable

# %%
from pyairtable import Api, Base
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
AIRTABLE_PAT = os.getenv('AIRTABLE_PAT')
BASE_ID = os.getenv('BASE_ID')
TABLE_NAME = 'Listings'

# %%
api = Api(AIRTABLE_PAT)
base = Base(api, BASE_ID)
table = base.table(TABLE_NAME)

# %%
records = []

for city in listings_details.keys():
    listings_details_lst = listings_details[city]
    
    for listing in listings_details_lst:
        records.append(listing)

# %%
for r in records:
    table.create(r)

# %% [markdown]
# ## Export in Pandas

# %%
import pandas as pd

# %%
source_B_df = pd.DataFrame(records)

# %%
source_B_df.to_csv('source_B_listings_only.csv')
